# %%
import pandas as pd

e_cars = pd.read_csv("e-cars.csv",sep=";")
mall_customers = pd.read_csv("mall_customers.csv",sep=",")
titanic_data = pd.read_csv("titanic_data.csv",sep=",")
airbnb_reviews = pd.read_csv("airbnb_new_york_city_reviews.csv",sep=",")
airbnb_listings = pd.read_csv("airbnb_new_york_city_listings.csv",sep=",")

#E_cars
e_cars_filtered = e_cars.loc[e_cars["RATING"].notna()].reset_index(inplace=False, drop=True)

e_cars_filtered2 = e_cars.drop(columns = ["RATING"])

#Mall_cust
mall_customers.index.name="Index"

#Titanic_data
titanic_data_filtered = titanic_data.loc[titanic_data["Cabin"].notna()].reset_index(inplace=False, drop=True)

#AIRBNB rev
airbnb_reviews.index.name="Index"

#AIRBNB list
airbnb_listings_filtered = airbnb_listings.loc[airbnb_listings["reviews_per_month"].notna() | airbnb_listings["last_review"].notna()].reset_index(inplace=False, drop=True)
airbnb_listings_filtered

airbnb_listings_filtered2 = airbnb_listings.drop(columns = ["reviews_per_month","last_review"])


####BIRANJE PRIKAZA
#e_cars_filtered
#e_cars_filtered2
#mall_customers.dropna(how='all')
#titanic_data_filtered
#airbnb_reviews
#airbnb_listings_filtered
#airbnb_listings_filtered2
# Out:
#              id                                               name   host_id  \
# 0          2595                              Skylit Midtown Castle      2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...      4869
# 2          5121                                    BlissArtsSpace!      7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden      7378
# 4          5178                   Large Furnished Room Near B'way　      8967
# ...         ...                                                ...       ...
# 36719  51447515         Gorgeous 2 Bedroom - in Prime Midtown East  51589519
# 36720  51449962  Charming UWS 1-bdrm, 1-office, 1/2 block to Ct...   2971741
# 36721  51450816                                    The Hunter IIII  61391963
# 36722  51451029                        Rockaway Beach Surf Getaway  10123226
# 36723  51451368                       Nyc apt in the middle in nyc  17770287
#
# ...
