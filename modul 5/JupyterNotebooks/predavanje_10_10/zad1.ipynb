# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
covid_df = pd.read_csv("casedistribution.csv", parse_dates=["dateRep"])
covid_df
# Out:
# C:\Users\damja\AppData\Local\Temp\ipykernel_15028\422410209.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   covid_df = pd.read_csv("casedistribution.csv", parse_dates=["dateRep"])
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-12-14   14     12  2020    746       6             Afghanistan
# 1     2020-12-13   13     12  2020    298       9             Afghanistan
# 2     2020-12-12   12     12  2020    113      11             Afghanistan
# 3     2020-11-12   11     12  2020     63      10             Afghanistan
# 4     2020-10-12   10     12  2020    202      16             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 61895 2020-03-25   25      3  2020      0       0                Zimbabwe
# ...

# %%
plt.plot(covid_df.dateRep, covid_df.cases)
covid_df.cases
# Out:
# 0        746
# 1        298
# 2        113
# 3         63
# 4        202
#         ...
# 61895      0
# 61896      0
# 61897      0
# 61898      1
# 61899      1
# Name: cases, Length: 61900, dtype: int64

# %%
var_graf = covid_df.groupby("dateRep", as_index=False).mean(numeric_only=False)
plt.plot(var_graf.dateRep, var_graf.cases)
# Out:
# C:\Users\damja\AppData\Local\Temp\ipykernel_15028\160849059.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   var_graf = covid_df.groupby("dateRep", as_index=False).mean(numeric_only=False)

# %%
okvir = plt.figure()

# %%
#default
plt.rcdefaults()

# %%
okvir = plt.figure(figsize=(8,8))
vanjski_graf = okvir.add_axes([0.1,0.1, 0.9,0.9])
unutarnji_graf = okvir.add_axes([0.7,0.7, 0.25, 0.25])

# %% [markdown]
# Promjenom parametara metode add_axes(), pozicionirajte unutarnji okvir u:
#
# gornji lijevi kut
# donji lijevi kut
# sredinu

# %%
#gornji lijevi kut
okvir = plt.figure(figsize=(8,8))
vanjski_graf = okvir.add_axes([0.1,0.1, 0.9,0.9])
unutarnji_graf = okvir.add_axes([0.2,0.7, 0.25, 0.25])

# %%
#donji lijevi kut
okvir = plt.figure(figsize=(8,8))
vanjski_graf = okvir.add_axes([0.1,0.1, 0.9,0.9])
unutarnji_graf = okvir.add_axes([0.2,0.2, 0.25, 0.25])

# %%
#sredina
okvir = plt.figure(figsize=(8,8))
vanjski_graf = okvir.add_axes([0.1,0.1, 0.9,0.9])
unutarnji_graf = okvir.add_axes([0.45,0.45, 0.25, 0.25])

# %%
okvir = plt.figure(figsize=(8,8))
gs = okvir.add_gridspec(3,3)

gore_lijevo = okvir.add_subplot(gs[0,0]) #prvi red, prvi stupac
gore_sredina = okvir.add_subplot(gs[1,0]) #prvi red, drugi stupac
gore_desno = okvir.add_subplot(gs[:2,1:]) #prva 2 reda i stupci od indeksa 1 nadalje

dolje = okvir.add_subplot(gs[2,:]) #treci red, svi stupci

# %% [markdown]
# Promjenom parametara metoda add_gridspec() i add_subplot(), kreirajte gornji raspored okvira kao u ogledalu.
# Promjenom parametara metoda add_gridspec() i add_subplot(), kreirajte raspored okvira tako da je jedan okvir unutar svake ćelije.
# Promjenom parametara metoda add_gridspec() i add_subplot(), kreirajte raspored okvira tako da je jedan okvir unutar svakog reda.
# Promjenom parametara metoda add_gridspec() i add_subplot(), kreirajte raspored okvira tako da je jedan okvir unutar svakog stupca.

# %%
#ogledalo
okvir = plt.figure(figsize=(8,8))
gs = okvir.add_gridspec(3,3)

gore_desno = okvir.add_subplot(gs[0,2]) #prvi red, treci stupac
sredina_desno = okvir.add_subplot(gs[1,2]) #drugi red, treci stupac
gore_lijevo = okvir.add_subplot(gs[:2,0:2]) #prva 2 reda i stupci od indeksa 0 do 2

dolje = okvir.add_subplot(gs[2,:]) #treci red, svi stupci

# %%
#samo celije
okvir = plt.figure(figsize=(8,8))
gs = okvir.add_gridspec(3,3)

gore_lijevo = okvir.add_subplot(gs[0,0]) #prvi red, prvi stupac
gore_sredina = okvir.add_subplot(gs[0,1]) #prvi red, drugi stupac
gore_desno = okvir.add_subplot(gs[0,2]) #prvi red, treci stupac

sredina_lijevo = okvir.add_subplot(gs[1,0]) #drugi red, prvi stupac
sredina_sredina = okvir.add_subplot(gs[1,1]) #drugi red, drugi stupac
sredina_desno = okvir.add_subplot(gs[1,2]) #drugi red, treci stupac

dolje_lijevo = okvir.add_subplot(gs[2,0]) #treci red, prvi stupac
dolje_sredina = okvir.add_subplot(gs[2,1]) #treci red, drugi stupac
dolje_desno = okvir.add_subplot(gs[2,2]) #treci red, treci stupac

# %%
#puni redovi
okvir = plt.figure(figsize=(8,8))
gs = okvir.add_gridspec(3,3)

gore = okvir.add_subplot(gs[0,:]) #prvi red, svi stupci
sredina = okvir.add_subplot(gs[1,:]) #prvi red, svi stupci
dolje = okvir.add_subplot(gs[2,:]) #prvi red, svi stupci

# %%
#samo stupci
okvir = plt.figure(figsize=(8,8))
gs = okvir.add_gridspec(3,3)

lijevo = okvir.add_subplot(gs[:,0]) #svi redovi, prvi stupac
sredina = okvir.add_subplot(gs[:,1]) #svi redovi, drugi stupac
desno = okvir.add_subplot(gs[:,2]) #svi redovi, treci stupac

# %%
okvir, osi = plt.subplots(2,3)

# %%
###
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html
###

# %%
mall_customers_df = pd.read_csv("mall_customers.csv")
mall_customers_df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
mall_customers_df.plot()
# Out:
# <Axes: >

# %%
covid_df.plot()
# Out:
# <Axes: >
# Error in callback <function _draw_all_if_interactive at 0x0000020837F511C0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\Programiranje\Anaconda\Lib\site-packages\matplotlib\pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File C:\Programiranje\Anaconda\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File C:\Programiranje\Anaconda\Lib\site-packages\matplotlib\backend_bases.py:2082, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2080 if not self._is_idle_drawing:
#    2081     with self._idle_draw_cntx():
# ...
