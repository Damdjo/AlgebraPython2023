# %%
import pandas as pd
earthquakes_df = pd.read_csv("earthquakes.csv")

# %%
from pandas.plotting import autocorrelation_plot
mall_customers_df = pd.read_csv("mall_customers.csv")

autocorrelation_plot(mall_customers_df["Age"])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
autocorrelation_plot(mall_customers_df["Spending Score (1-100)"])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
mall_customers_df.corr()
# Out:
# C:\Users\damja\AppData\Local\Temp\ipykernel_9192\663055493.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mall_customers_df.corr()
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %%
autocorrelation_plot(mall_customers_df["Age"])
autocorrelation_plot(mall_customers_df["Spending Score (1-100)"])
autocorrelation_plot(mall_customers_df["Annual Income (k$)"])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
Na stranici https://www.gapminder.org/data/ preuzmite po jednu csv datoteku (po izboru) iz:

Economy
Communication
Education
Preuzete podatke iz skupina podataka obradite pomoću Pandas biblioteke tako da ih prilagodite za
vizualizaciju i daljnju obradu. Prilikom obrade podataka, osim tabličnog prikaza, koristite
i grafove kako biste uočili neke anomalije u podacima.

Nakon što ste obradili podatke, koristeći sve grafove koje smo do sada naučili
(ako mislite da je važno za bolju vizualizaciju podatka, dodajte i drugi tip grafa, koji nismo ovdje obradili),
prikažite grafički obrađene podatke.

# %%
broadband_subs_df = pd.read_csv("zad/broadband_subscribers.csv")
total_cell_phones_df = pd.read_csv("zad/cell_phones_total.csv")
internet_users_percent_df = pd.read_csv("zad/internet_users.csv")
net_users_total_df = pd.read_csv("zad/net_users_num.csv")
pc_total_df = pd.read_csv("zad/personal_computers_total.csv")

# %%
broadband_subs_df.loc[ : , broadband_subs_df.columns!="country"]
broadband_subs_df["1998"].fillna(0,inplace=True)
broadband_subs_df
# Out:
#           country 1998 1999 2000 2001  2002   2003  2004   2005   2006  ...  \
# 0           Aruba    0  NaN  NaN  NaN   NaN   1400  6960  12.3k    14k  ...
# 1     Afghanistan    0  NaN  NaN  NaN   NaN    NaN   200    220    500  ...
# 2          Angola    0  NaN  NaN  NaN   NaN    NaN   NaN    NaN   7460  ...
# 3         Albania    0  NaN  NaN  NaN   NaN    NaN   NaN    272    272  ...
# 4         Andorra    0  NaN  NaN  NaN  1150   3600  6280  10.3k  14.6k  ...
# ..            ...  ...  ...  ...  ...   ...    ...   ...    ...    ...  ...
# 202         Samoa    0  NaN  NaN  NaN   NaN    NaN    32     65     98  ...
# 203         Yemen    0  NaN  NaN  NaN   NaN    NaN   NaN   1500   2780  ...
# 204  South Africa    0  NaN  NaN  NaN  2670  20.3k   60k   165k   335k  ...
# 205        Zambia    0  NaN   21   31    48     91   250    250   2340  ...
# 206      Zimbabwe    0  NaN  NaN  771  2850   6390  8970  10.2k  10.2k  ...
#
# ...

# %%
broadband_subs_df.ffill(axis = 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 broadband_subs_df.ffill(axis = 1, inplace=True)
#
# AttributeError: 'function' object has no attribute 'ffill'

# %%
broadband_subs_df.convert_dtypes
broadband_subs_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 broadband_subs_df.convert_dtypes
#       2 broadband_subs_df
#
# AttributeError: 'function' object has no attribute 'convert_dtypes'
