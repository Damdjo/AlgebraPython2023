# %%
"""
# %Y - godina zapisana kao četveroznamenkasti broj
# %y - godina zapisana kao dvoznamenkasti broj (21 za 2021. godinu)
# %m - mjesec zapisan kao dvoznamenkasti broj (01, 02, 12)
# %d - dan zapisan kao dvoznamenkasti broj (01, 02, 23, 31)
# %H - sat u 24-satnom formatu zapisa (00, 01, 23)
# %I - sat u 12-satnom formatu zapisa (00, 01, 12)
# %M - minute zapisane kao dvoznamenkasti broj (01, 02, 59)
# %S - sekunde zapisane kao dvoznamenkasti broj (01, 02, 59)
# %w - dan u tjednu kao broj od 0 do 6 za ponedjeljak do nedjelje
# %U - dvoznamenkasti broj tjedna u godini. Nedjelja se smatra prvim danom u tjednu i dani poslije prve nedjelje u godini smatraju se dijelom 00 tjedna.
# %W - dvoznamenkasti broj tjedna u godini. Ponedjeljak se smatra prvim danom u tjednu i dani poslije prve nedjelje u godini smatraju se dijelom 00 tjedna.
# %z - odstupanje od UTC vremenske zone kao +HHHH ili -HHHH (sati).
# %F - skraćeni oblik za format: %Y-%m-%d (2021-9-18)
# %D - skraćeni oblik za format: %m/%d/%y (09/18/21) 7:46 PM
"""

# %%
#ZADATAK
"""
Napravite aplikaciju koja će generirati nasumične podatke, tako da simulira dnevni rast temperature od jutra 
do poslijepodneva i zatim pad do ranog jutra. Podatke treba pohraniti u rječnik, tako da je ključ datum, 
a podaci lista parova vrijednosti (tuple) vremena i temperature. Temperatura treba biti izmjerena svakih 15 minuta.

Temperatura zraka od -25 do +39 stupnjeva Celzijusa
Početni datum i vrijeme trebaju biti uneseni od strane korisnika, a moraju biti minimalno dvije godine 
prije današnjeg datuma.
Podacima se mogu dodati i informacije o vlažnosti zraka (vrijednosti od 15% do 95%) te 
tlak zraka (990 hPa do 1035 hPa) 
"""

# %%
import random, numpy 
from datetime import datetime, date, time
import matplotlib.pyplot as plt

def temp_range():
    pass

def generiraj_podatak(date_month):
    pass


def get_curved_data(prosjek_podataka, broj_generiranih_brojeva):
    
    mean, sigma = prosjek_podataka, 7 # mean and standard deviation

    gen_lista = numpy.random.normal(prosjek_podataka, sigma, broj_generiranih_brojeva)
    
    count, bins, ignored = plt.hist(s, broj_generiranih_brojeva, density=True, rwidth = 0.5)

    plt.plot(bins, 1/(sigma * numpy.sqrt(2 * numpy.pi)) *

                   numpy.exp( - (bins - mu)**2 / (2 * sigma**2) ),

             linewidth=2, color='r')

    plt.show()

    return gen_lista

#TEST MJESEC
s = get_curved_data(15,100)
for counter, broj in enumerate(sorted(s)):
    print(counter+1, " ",broj)
# Out:
# 1   -3.976660584311155
# 2   -3.6883432215381298
# 3   -1.170438712814704
# 4   2.9567398043024102
# 5   4.839261095535694
# 6   5.926710563554506
# 7   6.009838389694195
# 8   6.999809198032549
# 9   7.1949068804786185
# 10   7.399633121697809
# 11   7.80595131875595
# 12   7.8427043524641515
# 13   7.888494758046547
# 14   7.915437577336184
# 15   7.958621435899675
# 16   8.827010270251744
# 17   8.937524688784888
# 18   9.602182434076877
# 19   9.610647076031585
# 20   9.812465502703008
# 21   9.994073104825736
# 22   10.166236731375182
# 23   10.347297833488371
# 24   10.368630580773349
# 25   10.702886423748392
# 26   10.752870014864627
# 27   10.839768611066566
# 28   10.85994360004345
# 29   10.883839024278846
# 30   11.153718613021606
# 31   11.255950746500163
# 32   11.587210563140815
# 33   11.63850087365012
# 34   11.668871456447825
# 35   12.044964569528274
# 36   12.343274728642136
# 37   12.455945866461647
# 38   12.589203377916267
# 39   12.652491697111564
# ...
