# %%
###
#    https://opendata.ecdc.europa.eu/covid19/casedistribution/csv 
###
#    https://opendata.ecdc.europa.eu/covid19/casedistribution/ 
###

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import pandas as pd
covid_df = pd.read_csv("casedistribution.csv", parse_dates=["dateRep"], dayfirst=True)
covid_df
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-12-14   14     12  2020    746       6             Afghanistan
# 1     2020-12-13   13     12  2020    298       9             Afghanistan
# 2     2020-12-12   12     12  2020    113      11             Afghanistan
# 3     2020-12-11   11     12  2020     63      10             Afghanistan
# 4     2020-12-10   10     12  2020    202      16             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 61895 2020-03-25   25      3  2020      0       0                Zimbabwe
# 61896 2020-03-24   24      3  2020      0       1                Zimbabwe
# 61897 2020-03-23   23      3  2020      0       0                Zimbabwe
# 61898 2020-03-22   22      3  2020      1       0                Zimbabwe
# 61899 2020-03-21   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
plt.plot(covid_df.dateRep, covid_df.cases)

# %%
var_graf = covid_df.groupby("dateRep", as_index=False).mean(numeric_only=False)
plt.plot(var_graf.dateRep, covid_df.cases)
# Out:
# C:\Users\damja\AppData\Local\Temp\ipykernel_15228\3359846299.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   var_graf = covid_df.groupby("dateRep", as_index=False).mean(numeric_only=False)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 var_graf = covid_df.groupby("dateRep", as_index=False).mean(numeric_only=False)
# ----> 2 plt.plot(var_graf.dateRep, covid_df.cases)
#
# File C:\Programiranje\Anaconda\Lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
# ...

# %%
#[marker][stil_linije][boja] 
##  https://matplotlib.org/2.1.1/api/_as_gen/matplotlib.pyplot.plot.html 
plt.plot(var_graf.dateRep, covid_df.cases, "ob")
