# %%
import pandas as pd

# %%
ocjene_df = pd.read_csv("ocjene.csv")
ocjene_df["address"] = ocjene_df["address"].apply(lambda x: x.replace(',', ''))
ocjene_df
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                         address
# 0         9253 Richardson Road Matawan NJ 07747
# 1                33 Spring Dr. Taunton MA 02780
# 2                41 Hill Avenue Mentor OH 44060
# ...

# %%
ocjene_df = pd.read_csv("ocjene.csv")
ocjene_df["fname"] = ocjene_df["fname"].str.strip()
ocjene_df["lname"] = ocjene_df["lname"].str.strip()
ocjene_df["gender"] = ocjene_df["gender"].str.strip()
ocjene_df["address"] = ocjene_df["address"].str.strip()
ocjene_df.columns = ['Ime', 'Prezime', 'Spol', 'Dob', 'Sati_Tjednog_Vjezbanja', 'Sati_Tjednog_Ucenja', 'Ocjena', 'Puna_Adresa']
ocjene_df.columns = [x.lower() for x in ocjene_df.columns]

# %%
ocjene_df.sort_values(by = "dob",ascending=True)
# Out:
#             ime    prezime    spol  dob  sati_tjednog_vjezbanja  \
# 920     Nichole      Blake  female   14                       3
# 277        Roth    Patrick    male   14                       2
# 579       Xenos       Snow    male   14                       2
# 1209       Carl     Nelson    male   14                       1
# 1213     Arthur     Nieves    male   14                       3
# ...         ...        ...     ...  ...                     ...
# 826       Hayes  Wilkinson    male   19                       5
# 1636    Kaitlin   Ferguson  female   19                       5
# 831        Noah      Mckay    male   19                       5
# 796   Alexandra    Guthrie  female   19                       4
# 1999      Linus     Morris    male   19                       4
#
#       sati_tjednog_ucenja  ocjena  \
# 920                     6    70.4
# 277                    13    90.4
# 579                    12    91.4
# 1209                   15    95.2
# ...

# %%
ocjene_df.sort_values(by = ["dob","sati_tjednog_ucenja"],ascending=[True, False])
# Out:
#             ime      prezime    spol  dob  sati_tjednog_vjezbanja  \
# 32      Georgia        Munoz  female   14                       5
# 89       Lucius      Herrera    male   14                       2
# 351       Nehru      Ballard    male   14                       1
# 1029      Clare  Fitzpatrick  female   14                       4
# 1269  Valentine     Cummings    male   14                       5
# ...         ...          ...     ...  ...                     ...
# 1870       Levi      Coleman    male   19                       3
# 1278    Barclay      Nichols    male   19                       0
# 1359        Jin       Valdez    male   19                       2
# 1449    Gillian       Norris  female   19                       5
# 1931       Luke     Morrison    male   19                       5
#
#       sati_tjednog_ucenja  ocjena  \
# 32                     20    99.0
# 89                     19    88.0
# 351                    19    93.3
# ...

# %%
listings_df = pd.read_csv("airbnb_new_york_city_listings.csv")
reviews_df = pd.read_csv("airbnb_new_york_city_reviews.csv")
listings_df
listings_df.drop(["latitude","longitude","calculated_host_listings_count"],axis=1,inplace=True)

# %%
listings_df.sort_values(by = ["price","reviews_per_month","availability_365"],ascending=[True, False, False])
# Out:
#              id                                          name    host_id  \
# 26819  42065543                          Broadway Plaza Hotel  307634016
# 26612  41792753                         Mint House At 70 Pine  197053492
# 26823  42065562                                 Artezen Hotel  307633956
# 30399  46251446                      citizenM New York Bowery  374516933
# 30204  46059074          CITIZENM NEW YORK TIMES SQUARE HOTEL  373324108
# ...         ...                                           ...        ...
# 20324  31219800                              ~New jersey loft  172226912
# 32207  48097641                                The house of M  252048159
# 24888  39574087  The Allen Hotel, Deluxe Penthouse King Suite  266741420
# 24499  39100961    Chambers Hotel, Chambers Hotel Queen - ADA  220229838
# 15760  22436899                           1-BR Lincoln Center   72390391
#
#                    host_name neighbourhood_group       neighbourhood  \
# ...

# %%
reviews_df
reviews_df.sort_values(by = "date",ascending=True)
# Out:
#         listing_id        date
# 1110          5803  2009-04-23
# 507           5178  2009-05-06
# 1111          5803  2009-05-17
# 508           5178  2009-05-23
# 1302          6848  2009-05-25
# ...            ...         ...
# 838934    50841755  2021-08-04
# 784049    40655194  2021-08-04
# 419887    15158791  2021-08-04
# 835680    49617564  2021-08-04
# 839320    51344110  2021-08-04
#
# [839321 rows x 2 columns]

# %%
listings_df["minimal_revenue"] = listings_df["price"] * listings_df["minimum_nights"]

listings_df["last_review"].fillna("01-01-1970", inplace = True)
listings_df["last_review"] = pd.to_datetime(listings_df["last_review"])
listings_df["last_review_year"] = listings_df["last_review"].dt.year
listings_df["last_review_year"] = pd.to_numeric(listings_df["last_review_year"])
listings_df["last_review_year"] = listings_df["last_review_year"].astype("int64")
listings_df[["room_type","price","minimal_revenue"]].groupby("room_type", as_index=False).mean()
# Out:
#          room_type       price  minimal_revenue
# 0  Entire home/apt  213.324779      4949.334480
# 1       Hotel room  293.262548      2662.552124
# 2     Private room   96.617690      1963.337077
# 3      Shared room  107.978297      2575.096828

# %%
listings_df[["room_type", "last_review_year", "price", "minimal_revenue"]].groupby(["room_type", "last_review_year"], as_index=False).mean()
# Out:
#           room_type  last_review_year       price  minimal_revenue
# 0   Entire home/apt              1970  262.485149      7906.647085
# 1   Entire home/apt              2010  228.000000       228.000000
# 2   Entire home/apt              2011  191.800000      5754.000000
# 3   Entire home/apt              2012  156.000000      5992.882353
# 4   Entire home/apt              2013  170.666667      6182.037037
# 5   Entire home/apt              2014  184.879032      7935.516129
# 6   Entire home/apt              2015  228.021739      6890.673913
# 7   Entire home/apt              2016  187.533696      5540.232609
# 8   Entire home/apt              2017  205.882831      6801.602088
# 9   Entire home/apt              2018  178.282708      5878.611162
# 10  Entire home/apt              2019  197.652335      5491.085992
# 11  Entire home/apt              2020  194.514196      4853.522082
# 12  Entire home/apt              2021  201.914445      2084.742582
# ...

# %%
ocjene_df[["spol", "dob", "sati_tjednog_vjezbanja", "sati_tjednog_ucenja", "ocjena"]].groupby(["dob", "spol"], as_index=False).mean()
# Out:
#     dob    spol  sati_tjednog_vjezbanja  sati_tjednog_ucenja     ocjena
# 0    14  female                3.132911            10.658228  82.058228
# 1    14    male                2.822785            11.170886  82.323418
# 2    15  female                2.943038            11.050633  82.905696
# 3    15    male                3.021127            10.866197  82.671831
# 4    16  female                3.132911            11.158228  82.582278
# 5    16    male                2.994318            11.465909  82.752841
# 6    17  female                3.146893            10.943503  83.599435
# 7    17    male                2.927374            11.268156  82.949721
# 8    18  female                2.978022            10.950549  82.500000
# 9    18    male                2.982036            10.856287  82.103593
# 10   19  female                2.952096            10.832335  82.592216
# 11   19    male                2.977528            10.612360  81.598315

# %%
ocjene_df.corr(numeric_only=["dob","sati_tjednog_vjezbanja","sati_tjednog_ucenja","ocjena"])
# Out:
#                              dob  sati_tjednog_vjezbanja  sati_tjednog_ucenja  \
# dob                     1.000000               -0.003643            -0.017467
# sati_tjednog_vjezbanja -0.003643                1.000000             0.021105
# sati_tjednog_ucenja    -0.017467                0.021105             1.000000
# ocjena                 -0.007580                0.161286             0.801955
#
#                           ocjena
# dob                    -0.007580
# sati_tjednog_vjezbanja  0.161286
# sati_tjednog_ucenja     0.801955
# ocjena                  1.000000

# %%
listings_df.corr()
# Out:
# C:\Users\damja\AppData\Local\Temp\ipykernel_14892\979701697.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   listings_df.corr()
#                          id   host_id     price  minimum_nights  \
# id                 1.000000  0.592363  0.018652       -0.107520
# host_id            0.592363  1.000000  0.008857       -0.103647
# price              0.018652  0.008857  1.000000       -0.004452
# minimum_nights    -0.107520 -0.103647 -0.004452        1.000000
# number_of_reviews -0.294396 -0.126033 -0.030849       -0.143130
# reviews_per_month  0.178765  0.199711 -0.003088       -0.163251
# availability_365   0.229577  0.253292  0.069875       -0.020994
# minimal_revenue   -0.039593 -0.036073  0.623080        0.376846
# last_review_year  -0.228369 -0.137531 -0.053057       -0.144535
#
# ...

# %%
###
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html#pandas.pivot_table
###

# %%
pd.pivot_table(ocjene_df,index = "spol")
# Out:
# C:\Users\damja\AppData\Local\Temp\ipykernel_14892\3891688915.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(ocjene_df,index = "spol")
#            dob   ocjena  sati_tjednog_ucenja  sati_tjednog_vjezbanja
# spol
# female  16.568  82.7173               10.932                   3.047
# male    16.589  82.3948               11.045                   2.954

# %%
pd.pivot_table(ocjene_df, values=["ocjena"], index=["spol"], aggfunc="mean")
# Out:
#          ocjena
# spol
# female  82.7173
# male    82.3948

# %% [markdown]
# Očigledno argument aggfunc predstavlja vrijednost funkcije po kojoj se agregira,
# odnosno grupira, odnosno predstavlja statističku vrijednost koju računamo.
# Probajte mijenjati aggfunc argument nazivima statističkih metoda u Pandasu te uz kolonu ocjene,
# dodajte i sate tjednog učenja (otkrili smo da su u koleraciji)

# %%
pd.pivot_table(ocjene_df, values=["ocjena", "sati_tjednog_ucenja"], index=["spol"], aggfunc="mean")
# Out:
#          ocjena  sati_tjednog_ucenja
# spol
# female  82.7173               10.932
# male    82.3948               11.045

# %%
pd.pivot_table(ocjene_df, values=["ocjena", "sati_tjednog_ucenja"], index=["spol"], aggfunc="max")
# Out:
#         ocjena  sati_tjednog_ucenja
# spol
# female   100.0                   20
# male     100.0                   20

# %%
pd.pivot_table(ocjene_df, values=["ocjena", "sati_tjednog_ucenja"], index=["spol"], aggfunc="min")
# Out:
#         ocjena  sati_tjednog_ucenja
# spol
# female    32.0                    2
# male      43.0                    0

# %%
import numpy as np
pd.pivot_table(ocjene_df, values=["ocjena", "sati_tjednog_ucenja"], index=["spol"], aggfunc={"ocjena": [ np.mean, min, max],
                                                                                            "sati_tjednog_ucenja": [ np.mean, min, sum]})
# Out:
#        ocjena                sati_tjednog_ucenja
#           max     mean   min                mean min    sum
# spol
# female  100.0  82.7173  32.0              10.932   2  10932
# male    100.0  82.3948  43.0              11.045   0  11045
