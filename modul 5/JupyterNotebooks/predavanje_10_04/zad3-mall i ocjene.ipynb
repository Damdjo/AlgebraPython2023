# %%
import pandas as pd

mall_customers_df = pd.read_csv("mall_customers.csv")
ocjene_df = pd.read_csv("ocjene.csv")

# %%
mall_customers_df.isna().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
ocjene_df.isna().sum()
# Out:
# fname       0
# lname       0
# gender      0
# age         0
# exercise    0
# hours       0
# grade       0
# address     0
# dtype: int64

# %%
mall_customers_df.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
ocjene_df.dtypes
# Out:
# fname        object
# lname        object
# gender       object
# age           int64
# exercise      int64
# hours         int64
# grade       float64
# address      object
# dtype: object

# %%
mall_customers_df["Gender"] = mall_customers_df["Gender"].str.strip()
mall_customers_df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
ocjene_df["fname"] = ocjene_df["fname"].str.strip()
ocjene_df["lname"] = ocjene_df["lname"].str.strip()
ocjene_df["gender"] = ocjene_df["gender"].str.strip()
ocjene_df["address"] = ocjene_df["address"].str.strip()
ocjene_df
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 0         9253 Richardson Road, Matawan, NJ 07747
# 1                33 Spring Dr., Taunton, MA 02780
# 2                41 Hill Avenue, Mentor, OH 44060
# ...

# %%
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html?highlight=drop#pandas.DataFrame.drop

listings_df = pd.read_csv("airbnb_new_york_city_listings.csv")

# %%
listings_df.drop(["latitude", "longitude"], axis=1)

listings_df.drop(["id", "name", "host_id", "host_name"], axis=1)
# Out:
#       neighbourhood_group       neighbourhood   latitude  longitude  \
# 0               Manhattan             Midtown  40.753560 -73.985590
# 1                Brooklyn  Bedford-Stuyvesant  40.684940 -73.957650
# 2                Brooklyn  Bedford-Stuyvesant  40.685350 -73.955120
# 3                Brooklyn         Sunset Park  40.662650 -73.994540
# 4               Manhattan             Midtown  40.764570 -73.983170
# ...                   ...                 ...        ...        ...
# 36719           Manhattan             Midtown  40.755787 -73.965126
# 36720           Manhattan     Upper West Side  40.787029 -73.969239
# 36721           Manhattan     Upper East Side  40.768950 -73.960455
# 36722              Queens             Arverne  40.599257 -73.797953
# 36723           Manhattan         Murray Hill  40.748655 -73.981209
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
listings_df.drop(["id", "name", "host_id", "host_name"], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 listings_df.drop(["id", "name", "host_id", "host_name"], axis=1, inplace=True)
#       2 listings_df.isnull().sum()
#
# File C:\Programiranje\Anaconda\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\Programiranje\Anaconda\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
ocjene_df.columns
# Out:
# Index(['fname', 'lname', 'gender', 'age', 'exercise', 'hours', 'grade',
#        'address'],
#       dtype='object')

# %%
#1
"""
ocjene_df.columns = ['Ime', 'Prezime', 'Spol', 'Dob', 'Sati_Tjednog_Vjezbanja',
                     'Sati_Tjednog_Ucenja', 'Ocjena', 'Puna_Adresa']
"""

# %%
#2
"""
kolone = list(ocjene_df.columns.values) 
kolone[0] = 'Ime'
kolone[1] = 'Prezime'
kolone[2] = 'Spol'
kolone[3] = 'Dob'
kolone[4] = 'Sati_Tjednog_Vjezbanja'
kolone[5] = 'Sati_Tjednog_Ucenja'
kolone[6] = 'Ocjena'
kolone[7] = 'Puna_Adresa' 
ocjene_df.columns = kolone 
"""

# %%
#3
"""
ocjene_df.rename(
    columns={
        'fname': 'Ime',
        'lname': 'Prezime',
        'gender': 'Spol',
        'age': 'Dob',
        'exercise': 'Sati_Tjednog_Vjezbanja',
        'hours': 'Sati_Tjednog_Ucenja',
        'grade': 'Ocjena',
        'address': 'Puna_Adresa'
    }
) 
"""

# %%
ocjene_df.columns = ['Ime', 'Prezime', 'Spol', 'Dob', 'Sati_Tjednog_Vjezbanja', 'Sati_Tjednog_Ucenja', 'Ocjena', 'Puna_Adresa']
ocjene_df
# Out:
#             Ime   Prezime    Spol  Dob  Sati_Tjednog_Vjezbanja  \
# 0        Marcia      Pugh  female   17                       3
# 1        Kadeem  Morrison    male   18                       4
# 2          Nash    Powell    male   18                       5
# 3       Noelani    Wagner  female   14                       2
# 4       Noelani    Cherry  female   18                       4
# ...         ...       ...     ...  ...                     ...
# 1995       Cody  Shepherd    male   19                       1
# 1996  Geraldine  Peterson  female   16                       4
# 1997   Mercedes      Leon  female   18                       3
# 1998     Lucius   Rowland    male   16                       1
# 1999      Linus    Morris    male   19                       4
#
#       Sati_Tjednog_Ucenja  Ocjena                                  Puna_Adresa
# 0                      10    82.4      9253 Richardson Road, Matawan, NJ 07747
# ...

# %%
#1 ocjene_df.columns = map(str.lower, ocjene_df.columns)
ocjene_df.columns = [x.lower() for x in ocjene_df.columns]
ocjene_df
# Out:
#             ime   prezime    spol  dob  sati_tjednog_vjezbanja  \
# 0        Marcia      Pugh  female   17                       3
# 1        Kadeem  Morrison    male   18                       4
# 2          Nash    Powell    male   18                       5
# 3       Noelani    Wagner  female   14                       2
# 4       Noelani    Cherry  female   18                       4
# ...         ...       ...     ...  ...                     ...
# 1995       Cody  Shepherd    male   19                       1
# 1996  Geraldine  Peterson  female   16                       4
# 1997   Mercedes      Leon  female   18                       3
# 1998     Lucius   Rowland    male   16                       1
# 1999      Linus    Morris    male   19                       4
#
#       sati_tjednog_ucenja  ocjena                                  puna_adresa
# 0                      10    82.4      9253 Richardson Road, Matawan, NJ 07747
# ...

# %%
mall_customers_df.columns = map(str.upper, mall_customers_df.columns)
mall_customers_df
# Out:
#      CUSTOMERID  GENDER  AGE  ANNUAL INCOME (K$)  SPENDING SCORE (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
listings_df
# Out:
#       neighbourhood_group       neighbourhood   latitude  longitude  \
# 0               Manhattan             Midtown  40.753560 -73.985590
# 1                Brooklyn  Bedford-Stuyvesant  40.684940 -73.957650
# 2                Brooklyn  Bedford-Stuyvesant  40.685350 -73.955120
# 3                Brooklyn         Sunset Park  40.662650 -73.994540
# 4               Manhattan             Midtown  40.764570 -73.983170
# ...                   ...                 ...        ...        ...
# 36719           Manhattan             Midtown  40.755787 -73.965126
# 36720           Manhattan     Upper West Side  40.787029 -73.969239
# 36721           Manhattan     Upper East Side  40.768950 -73.960455
# 36722              Queens             Arverne  40.599257 -73.797953
# 36723           Manhattan         Murray Hill  40.748655 -73.981209
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#any() - ako bilo gjde u popisu postoji traženi pojam
listings_df["neighbourhood_group"].str.contains("Manhattan").any()
# Out:
# True

# %%
#all() - ako u popisu svugdje postoji traženi pojam
listings_df["neighbourhood_group"].str.contains("Manhattan").all()
# Out:
# False

# %%
listings_df["neighbourhood_group"].str.contains("Manhattan")
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 36719     True
# 36720     True
# 36721     True
# 36722    False
# 36723     True
# Name: neighbourhood_group, Length: 36724, dtype: bool

# %%
listings_df.loc[listings_df["neighbourhood_group"].str.contains("Manhattan")==True]
# Out:
#       neighbourhood_group    neighbourhood   latitude  longitude  \
# 0               Manhattan          Midtown  40.753560 -73.985590
# 4               Manhattan          Midtown  40.764570 -73.983170
# 5               Manhattan  Upper West Side  40.803800 -73.967510
# 8               Manhattan      East Harlem  40.801070 -73.942550
# 9               Manhattan      East Harlem  40.787780 -73.947590
# ...                   ...              ...        ...        ...
# 36718           Manhattan  Upper East Side  40.767841 -73.958164
# 36719           Manhattan          Midtown  40.755787 -73.965126
# 36720           Manhattan  Upper West Side  40.787029 -73.969239
# 36721           Manhattan  Upper East Side  40.768950 -73.960455
# 36723           Manhattan      Murray Hill  40.748655 -73.981209
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0      Entire home/apt    150              30                 48  2019-11-04
# ...

# %%
ocjene_df
# Out:
#             ime   prezime    spol  dob  sati_tjednog_vjezbanja  \
# 0        Marcia      Pugh  female   17                       3
# 1        Kadeem  Morrison    male   18                       4
# 2          Nash    Powell    male   18                       5
# 3       Noelani    Wagner  female   14                       2
# 4       Noelani    Cherry  female   18                       4
# ...         ...       ...     ...  ...                     ...
# 1995       Cody  Shepherd    male   19                       1
# 1996  Geraldine  Peterson  female   16                       4
# 1997   Mercedes      Leon  female   18                       3
# 1998     Lucius   Rowland    male   16                       1
# 1999      Linus    Morris    male   19                       4
#
#       sati_tjednog_ucenja  ocjena                                  puna_adresa
# 0                      10    82.4      9253 Richardson Road, Matawan, NJ 07747
# ...

# %%
ocjene_df.loc[ (ocjene_df["spol"].str.contains("female")) & ~(ocjene_df["ocjena"]>70.0)]
# Out:
#             ime    prezime    spol  dob  sati_tjednog_vjezbanja  \
# 38      Rebekah      Brock  female   16                       2
# 61        Piper     Lowery  female   19                       2
# 62    Genevieve     Adkins  female   15                       1
# 98       Gisela   Johnston  female   19                       1
# 117       Debra  Wilkerson  female   16                       4
# ...         ...        ...     ...  ...                     ...
# 1910       Gail     Mcneil  female   17                       2
# 1942      Wilma      Tyler  female   19                       3
# 1965    Lavinia       Carr  female   16                       2
# 1974       Ella  Patterson  female   16                       1
# 1982      Kalia      Lewis  female   18                       1
#
#       sati_tjednog_ucenja  ocjena  \
# 38                      5    68.9
# 61                      5    61.4
# 62                      8    67.3
# 98                      8    68.0
# ...

# %%
price
minimum_nights
number_of_reviews
last_review
reviews_per_month
availability_365
last_review_year
minimal_revenue

# %%
#http://programarcadegames.com/index.php?chapter=formatting&lang=en

print("CIJENA")
print('-' * 50)
print(f"Naziv vrijednosti\t\t\tVrijednost")
print('-' * 50)
print(f"Minimalna cijena:\t\t{listings_df['price'].min():>10} USD")
print(f"Maksimalna cijena:\t\t{listings_df['price'].max():>10} USD")
print(f"Raspon cijena:\t\t\t{(listings_df['price'].max() - listings_df['price'].min()):>10} USD")
print(f"Prosječna cijena:\t\t{round(listings_df['price'].mean(), 2):>10} USD")
print(f"Medijan cijene:\t\t\t{round(listings_df['price'].median(), 2):>10} USD")
print(f"Standardna devijacija cijene:\t{round(listings_df['price'].std(), 2):>10} USD")
print(f"Ukupan broj vrijednosti cijena:\t{round(listings_df['price'].count(), 2):>10}")
print('-' * 50)
print('\n')
# Out:
# CIJENA
# --------------------------------------------------
# Naziv vrijednosti			Vrijednost
# --------------------------------------------------
# Minimalna cijena:		         0 USD
# Maksimalna cijena:		     10000 USD
# Raspon cijena:			     10000 USD
# Prosječna cijena:		    160.11 USD
# Medijan cijene:			     108.0 USD
# Standardna devijacija cijene:	    293.89 USD
# Ukupan broj vrijednosti cijena:	     36724
# --------------------------------------------------

# %%
listings_df.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  36724.000000  36724.000000  36724.000000    36724.000000
# mean      40.729355    -73.949582    160.109057       22.482083
# std        0.055562      0.049611    293.888431       28.361534
# min       40.508630    -74.241350      0.000000        1.000000
# 25%       40.689530    -73.983170     67.000000        3.000000
# 50%       40.725530    -73.954990    108.000000       30.000000
# 75%       40.762752    -73.931330    175.000000       30.000000
# max       40.911390    -73.705220  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       36724.000000       27309.000000                    36724.000000
# mean           22.854836           1.375435                       13.432306
# std            49.188479           3.850175                       46.293004
# min             0.000000           0.010000                        1.000000
# ...

# %%
listings_df.describe(include="all")
# Out:
#        neighbourhood_group       neighbourhood      latitude     longitude  \
# count                36724               36724  36724.000000  36724.000000
# unique                   5                 223           NaN           NaN
# top              Manhattan  Bedford-Stuyvesant           NaN           NaN
# freq                 16105                2690           NaN           NaN
# mean                   NaN                 NaN     40.729355    -73.949582
# std                    NaN                 NaN      0.055562      0.049611
# min                    NaN                 NaN     40.508630    -74.241350
# 25%                    NaN                 NaN     40.689530    -73.983170
# 50%                    NaN                 NaN     40.725530    -73.954990
# 75%                    NaN                 NaN     40.762752    -73.931330
# max                    NaN                 NaN     40.911390    -73.705220
#
# ...

# %%
listings_df.loc[listings_df["price"]>2600].mean(numeric_only=["price"])
# Out:
# latitude                            40.737673
# longitude                          -73.967437
# price                             5703.890909
# minimum_nights                      28.727273
# number_of_reviews                    5.800000
# reviews_per_month                    0.596154
# calculated_host_listings_count       2.400000
# availability_365                   169.345455
# dtype: float64
