# %%
import pandas as pd

reviews_df = pd.read_csv("airbnb_new_york_city_reviews_full.csv", parse_dates=["date"])

# %%
reviews_df
# Out:
#         listing_id                  id  ... reviewer_name                                           comments
# 0             2595               17857  ...          Jean  Notre séjour de trois nuits.\r<br/>Nous avons ...
# 1             2595               19176  ...          Cate                                  Great experience.
# 2             2595               19760  ...         Anita  I've stayed with my friend at the Midtown Cast...
# 3             2595               34320  ...       Kai-Uwe  We've been staying here for about 9 nights, en...
# 4             2595               46312  ...        Alicia  We had a wonderful stay at Jennifer's charming...
# ...            ...                 ...  ...           ...                                                ...
# 839316    51333702  419451978146866472  ...        Latyna                                   Very lovely home
# 839317    51337315  418916185474819186  ...           Vai  The host canceled this reservation the day bef...
# ...

# %%
reviews_df.dtypes
# Out:
# listing_id                int64
# id                        int64
# date             datetime64[ns]
# reviewer_id               int64
# reviewer_name            object
# comments                 object
# dtype: object

# %%
reviews_df.isna().sum()
# Out:
# listing_id         0
# id                 0
# date               0
# reviewer_id        0
# reviewer_name      7
# comments         812
# dtype: int64

# %%
reviews_df["comments"].fillna("No comments for listing", inplace=True)
reviews_df["reviewer_name"].fillna("J. Doe", inplace=True)

# %%
reviews_df
# Out:
#         listing_id                  id  ... reviewer_name                                           comments
# 0             2595               17857  ...          Jean  Notre séjour de trois nuits.\r<br/>Nous avons ...
# 1             2595               19176  ...          Cate                                  Great experience.
# 2             2595               19760  ...         Anita  I've stayed with my friend at the Midtown Cast...
# 3             2595               34320  ...       Kai-Uwe  We've been staying here for about 9 nights, en...
# 4             2595               46312  ...        Alicia  We had a wonderful stay at Jennifer's charming...
# ...            ...                 ...  ...           ...                                                ...
# 839316    51333702  419451978146866472  ...        Latyna                                   Very lovely home
# 839317    51337315  418916185474819186  ...           Vai  The host canceled this reservation the day bef...
# ...

# %%
reviews_df.isna().sum()
# Out:
# listing_id       0
# id               0
# date             0
# reviewer_id      0
# reviewer_name    0
# comments         0
# dtype: int64

# %%
reviews_df["reviewer_name"] = reviews_df["reviewer_name"].str.strip()
reviews_df["comments"] = reviews_df["comments"].str.strip()
